# %%
from crewai import Task, Agent, Crew
from utils.utils import get_openai_api_key
import os
from pathlib import Path

# %%
os.environ["OPENAI_API_KEY"] = get_openai_api_key()

# %%
# agent creation: Content Creator Agent
content_creator_assistant = Agent(
    name = "Content Creator Assistant",
    role="YouTube Shorts Micro-History Strategist",
    goal="Plan a 1-week slate of high-retention YouTube Shorts about surprising origins of everyday things.",
    backstory = (
        "You specialize in 30–45s micro-history that hooks fast, pays off with a twist, and drives comments. "
        "You keep ideas filmable by a solo creator at home with minimal props."
    ),
    llm = "gpt-4o-mini",
    verbose=True
)

# %%
# task creation: Plan YouTube Shorts Content
task = Task(
    description=( 
        "Create a 1-week video posting plan with 5 video blueprints. "
        "Platform: YouTube Shorts (vertical 9:16, 30-45s). "
        "Niche: Micro-History of Everyday Things (e.g., why pencils are yellow, origins of bubble wrap, etc.). "
        "Primary goals: 1) thumb-stop hook in first 1s, 2) crystal-clear narrative with a surprise, "
        "3) strong SEO phrasing in title/caption, 4) comment-bait CTA. "
        "Context: solo creator, home-filmable, no special gear. "
    ),
    expected_output=(
        '''
        Output a JSON array following the schema below, which contains a
        weekly schedule and 5 video blueprints. Each video blueprint should include:
        {
          "videos": [
            {
              "title": "<searchable, curiosity-driven title>",
              "hook_main": "<<=12 words, shows payoff fast>",
              "hook_alt": "<variant hook>",
              "visuals": ["simple prop or b-roll idea 1", "idea 2"],
              "tags": ["#microhistory","#everydaythings","#shorts"],
              "cta": "<question that invites comments>"
            }
          ]
        }
        '''
    ),
    agent=content_creator_assistant,
    verbose=True
    )

# %%
# crew creation and task execution
crew = Crew(
    agents=[content_creator_assistant], 
    tasks=[task],
    verbose=True,
)

results = crew.kickoff()
# Out:
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 3282d370-91ed-413c-b4ef-110f1bdd727f                                                                       │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: YouTube Shorts Micro-History Strategist                                                                 │
# │                                                                                                                 │
# │  Task: Create a 1-week video posting plan with 5 video blueprints. Platform: YouTube Shorts (vertical 9:16,     │
# │  30-45s). Niche: Micro-History of Everyday Things (e.g., why pencils are yellow, origins of bubble wrap,        │
# │  etc.). Primary goals: 1) thumb-stop hook in first 1s, 2) crystal-clear narrative with a surprise, 3) strong    │
# │  SEO phrasing in title/caption, 4) comment-bait CTA. Context: solo creator, home-filmable, no special gear.     │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: YouTube Shorts Micro-History Strategist                                                                 │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  [                                                                                                              │
# │      {                                                                                                          │
# │          "videos": [                                                                                            │
# │              {                                                                                                  │
# │                  "title": "Why Are Pencils Yellow? The Surprising Truth!",                                      │
# │                  "hook_main": "Think it’s just for looks? It’s much deeper!",                                   │
# │                  "hook_alt": "The color choice has a hidden history!",                                          │
# │                  "visuals": ["Show a yellow pencil", "Display various colored pencils"],                        │
# │                  "tags": ["#microhistory","#everydaythings","#shorts"],                                         │
# │                  "cta": "What’s your favorite pencil color and why?"                                            │
# │              }                                                                                                  │
# │          ]                                                                                                      │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │          "videos": [                                                                                            │
# │              {                                                                                                  │
# │                  "title": "The Secret Origin of Bubble Wrap: Not What You Think!",                              │
# │                  "hook_main": "You won’t believe bubble wrap’s original purpose!",                              │
# │                  "hook_alt": "Bubble wrap was invented for something totally different!",                       │
# │                  "visuals": ["Pop bubble wrap on camera", "Show an original packaging prototype"],              │
# │                  "tags": ["#microhistory","#everydaythings","#shorts"],                                         │
# │                  "cta": "What’s your best bubble wrap popping story?"                                           │
# │              }                                                                                                  │
# │          ]                                                                                                      │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │          "videos": [                                                                                            │
# │              {                                                                                                  │
# │                  "title": "Did You Know Chocolate Milk Has a Wild Origin?",                                     │
# │                  "hook_main": "Chocolate milk's history is anything but sweet!",                                │
# │                  "hook_alt": "The shocking start of chocolate milk will surprise you!",                         │
# │                  "visuals": ["Mixing chocolate syrup in milk", "Show a historical image of chocolate"],         │
# │                  "tags": ["#microhistory","#everydaythings","#shorts"],                                         │
# │                  "cta": "What’s your favorite way to enjoy chocolate?"                                          │
# │              }                                                                                                  │
# │          ]                                                                                                      │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │          "videos": [                                                                                            │
# │              {                                                                                                  │
# │                  "title": "The Bizarre Backstory of the Paperclip!",                                            │
# │                  "hook_main": "Why is this simple tool so significant?",                                        │
# │                  "hook_alt": "The paperclip's story will leave you shocked!",                                   │
# │                  "visuals": ["Bending a paperclip", "Show different paperclip designs"],                        │
# │                  "tags": ["#microhistory","#everydaythings","#shorts"],                                         │
# │                  "cta": "What’s the most creative use of a paperclip you know?"                                 │
# │              }                                                                                                  │
# │          ]                                                                                                      │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │          "videos": [                                                                                            │
# │              {                                                                                                  │
# │                  "title": "How Velcro Became a Household Name: The Unexpected Start!",                          │
# │                  "hook_main": "This popular fastener has a fascinating backstory!",                             │
# │                  "hook_alt": "Velcro wasn’t invented just for shoes or bags!",                                  │
# │                  "visuals": ["Showing Velcro in action", "Close-up of Velcro fastening"],                       │
# │                  "tags": ["#microhistory","#everydaythings","#shorts"],                                         │
# │                  "cta": "What other uses for Velcro can you think of?"                                          │
# │              }                                                                                                  │
# │          ]                                                                                                      │
# │      }                                                                                                          │
# │  ]                                                                                                              │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: 02948cd4-b8a7-4305-8969-f8f21bb96f77                                                                     │
# │  Agent: YouTube Shorts Micro-History Strategist                                                                 │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────── Trace Batch Finalization ──────────────────────────╮
# │ ✅ Trace batch finalized with session ID:                                    │
# │ cc5414ba-00fa-4172-bca0-bb4c8d984322                                         │
# │                                                                              │
# │ 🔗 View here:                                                                │
# │ https://app.crewai.com/crewai_plus/ephemeral_trace_batches/cc5414ba-00fa-417 │
# │ 2-bca0-bb4c8d984322?access_code=TRACE-7e1cc1095c                             │
# │ 🔑 Access Code: TRACE-7e1cc1095c                                             │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name: crew                                                                                                     │
# │  ID: 3282d370-91ed-413c-b4ef-110f1bdd727f                                                                       │
# │  Tool Args:                                                                                                     │
# │  Final Output: [                                                                                                │
# │      {                                                                                                          │
# │          "videos": [                                                                                            │
# │              {                                                                                                  │
# │                  "title": "Why Are Pencils Yellow? The Surprising Truth!",                                      │
# │                  "hook_main": "Think it’s just for looks? It’s much deeper!",                                   │
# │                  "hook_alt": "The color choice has a hidden history!",                                          │
# │                  "visuals": ["Show a yellow pencil", "Display various colored pencils"],                        │
# │                  "tags": ["#microhistory","#everydaythings","#shorts"],                                         │
# │                  "cta": "What’s your favorite pencil color and why?"                                            │
# │              }                                                                                                  │
# │          ]                                                                                                      │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │          "videos": [                                                                                            │
# │              {                                                                                                  │
# │                  "title": "The Secret Origin of Bubble Wrap: Not What You Think!",                              │
# │                  "hook_main": "You won’t believe bubble wrap’s original purpose!",                              │
# │                  "hook_alt": "Bubble wrap was invented for something totally different!",                       │
# │                  "visuals": ["Pop bubble wrap on camera", "Show an original packaging prototype"],              │
# │                  "tags": ["#microhistory","#everydaythings","#shorts"],                                         │
# │                  "cta": "What’s your best bubble wrap popping story?"                                           │
# │              }                                                                                                  │
# │          ]                                                                                                      │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │          "videos": [                                                                                            │
# │              {                                                                                                  │
# │                  "title": "Did You Know Chocolate Milk Has a Wild Origin?",                                     │
# │                  "hook_main": "Chocolate milk's history is anything but sweet!",                                │
# │                  "hook_alt": "The shocking start of chocolate milk will surprise you!",                         │
# │                  "visuals": ["Mixing chocolate syrup in milk", "Show a historical image of chocolate"],         │
# │                  "tags": ["#microhistory","#everydaythings","#shorts"],                                         │
# │                  "cta": "What’s your favorite way to enjoy chocolate?"                                          │
# │              }                                                                                                  │
# │          ]                                                                                                      │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │          "videos": [                                                                                            │
# │              {                                                                                                  │
# │                  "title": "The Bizarre Backstory of the Paperclip!",                                            │
# │                  "hook_main": "Why is this simple tool so significant?",                                        │
# │                  "hook_alt": "The paperclip's story will leave you shocked!",                                   │
# │                  "visuals": ["Bending a paperclip", "Show different paperclip designs"],                        │
# │                  "tags": ["#microhistory","#everydaythings","#shorts"],                                         │
# │                  "cta": "What’s the most creative use of a paperclip you know?"                                 │
# │              }                                                                                                  │
# │          ]                                                                                                      │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │          "videos": [                                                                                            │
# │              {                                                                                                  │
# │                  "title": "How Velcro Became a Household Name: The Unexpected Start!",                          │
# │                  "hook_main": "This popular fastener has a fascinating backstory!",                             │
# │                  "hook_alt": "Velcro wasn’t invented just for shoes or bags!",                                  │
# │                  "visuals": ["Showing Velcro in action", "Close-up of Velcro fastening"],                       │
# │                  "tags": ["#microhistory","#everydaythings","#shorts"],                                         │
# │                  "cta": "What other uses for Velcro can you think of?"                                          │
# │              }                                                                                                  │
# │          ]                                                                                                      │
# │      }                                                                                                          │
# │  ]                                                                                                              │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
# Display the content plan
print("=" * 80)
print("WEEKLY CONTENT PLAN")
print("=" * 80)
print(results.raw)
# Out:
# ================================================================================
# WEEKLY CONTENT PLAN
# ================================================================================
# [
#     {
#         "videos": [
#             {
#                 "title": "Why Are Pencils Yellow? The Surprising Truth!",
#                 "hook_main": "Think it’s just for looks? It’s much deeper!",
#                 "hook_alt": "The color choice has a hidden history!",
#                 "visuals": ["Show a yellow pencil", "Display various colored pencils"],
#                 "tags": ["#microhistory","#everydaythings","#shorts"],
#                 "cta": "What’s your favorite pencil color and why?"
#             }
#         ]
#     },
#     {
#         "videos": [
#             {
#                 "title": "The Secret Origin of Bubble Wrap: Not What You Think!",
#                 "hook_main": "You won’t believe bubble wrap’s original purpose!",
#                 "hook_alt": "Bubble wrap was invented for something totally different!",
#                 "visuals": ["Pop bubble wrap on camera", "Show an original packaging prototype"],
#                 "tags": ["#microhistory","#everydaythings","#shorts"],
#                 "cta": "What’s your best bubble wrap popping story?"
#             }
#         ]
#     },
#     {
#         "videos": [
#             {
#                 "title": "Did You Know Chocolate Milk Has a Wild Origin?",
#                 "hook_main": "Chocolate milk's history is anything but sweet!",
#                 "hook_alt": "The shocking start of chocolate milk will surprise you!",
#                 "visuals": ["Mixing chocolate syrup in milk", "Show a historical image of chocolate"],
#                 "tags": ["#microhistory","#everydaythings","#shorts"],
#                 "cta": "What’s your favorite way to enjoy chocolate?"
#             }
#         ]
#     },
#     {
#         "videos": [
#             {
#                 "title": "The Bizarre Backstory of the Paperclip!",
#                 "hook_main": "Why is this simple tool so significant?",
#                 "hook_alt": "The paperclip's story will leave you shocked!",
#                 "visuals": ["Bending a paperclip", "Show different paperclip designs"],
#                 "tags": ["#microhistory","#everydaythings","#shorts"],
#                 "cta": "What’s the most creative use of a paperclip you know?"
#             }
#         ]
#     },
#     {
#         "videos": [
#             {
#                 "title": "How Velcro Became a Household Name: The Unexpected Start!",
#                 "hook_main": "This popular fastener has a fascinating backstory!",
#                 "hook_alt": "Velcro wasn’t invented just for shoes or bags!",
#                 "visuals": ["Showing Velcro in action", "Close-up of Velcro fastening"],
#                 "tags": ["#microhistory","#everydaythings","#shorts"],
#                 "cta": "What other uses for Velcro can you think of?"
#             }
#         ]
#     }
# ]
